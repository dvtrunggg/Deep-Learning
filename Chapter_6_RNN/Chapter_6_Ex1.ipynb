# %% [markdown]
# ## **Chapter6: RNN & LSTN**
# ### **Ex1: One to one: international-airline-passengers**
# - Cho dữ liệu international-airline-passengers.csv.
# - Xây dựng model để dự đoán số hành khách cho thời gian tiếp theo
# - Giải thích cách tính tham số từ summary của model

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model, Sequential
from tensorflow.keras.layers import Dense, Input

from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV

# %%
# LSTM for international airline passengers problem with regression framing
import numpy
import matplotlib.pyplot as plt
import math
import pandas as pd
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# %cd '/content/gdrive/My Drive/LDS8_K275_ONLINE_DinhVietTrung'
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/LDS8_K275_ONLINE_DinhVietTrung

# %%
print(tf.__version__)
print(keras.__version__)
# Out:
# 2.8.2
# 2.8.0

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []

    for i in range(len(dataset)-look_back-1):
        #t
            a = dataset[i:(i+look_back), 0]
            dataX.append(a)
        #t+1
            dataY.append(dataset[i + look_back, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
# fix random seed for reproducibility
numpy.random.seed(7)

# %%
# load the dataset
dataframe = pd.read_csv('data/international-airline-passengers.csv', usecols=[1], engine='python')
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 1 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   passengers_in_thousands  144 non-null    int64
# dtypes: int64(1)
# memory usage: 1.2 KB

# %%
dataset = dataframe.values
dataset = dataset.astype('float32')
dataset[:10]
# Out:
# array([[112.],
#        [118.],
#        [132.],
#        [129.],
#        [121.],
#        [135.],
#        [148.],
#        [148.],
#        [136.],
#        [119.]], dtype=float32)

# %%
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %%
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
# reshape into X=t and Y=t+1
look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
# reshape input to be [samples, time steps, features]
trainX = numpy.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = numpy.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 4)                 96
#
#  dense (Dense)               (None, 1)                 5
#
# =================================================================
# Total params: 101
# Trainable params: 101
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ***Giải thích cách tính tham số***
# - lstm_1 (LSTM) = [(num_units + input_dim + 1) x num_units] x 4 = [(4 + 1 + 1) x 4] x 4 = 96
# - dense_1 = ((current layer n x previous layer n) + bias) = 1 x 4 + 1 = 5

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

history = model.fit(trainX, trainY,
                    validation_data=(testX, testY),
                    epochs=100,
                    batch_size=1)
# Out:
# Epoch 1/100
# 94/94 [==============================] - 3s 10ms/step - loss: 0.0407 - val_loss: 0.2532
# Epoch 2/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0208 - val_loss: 0.1884
# Epoch 3/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0167 - val_loss: 0.1615
# Epoch 4/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0154 - val_loss: 0.1450
# Epoch 5/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0143 - val_loss: 0.1377
# Epoch 6/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0131 - val_loss: 0.1231
# Epoch 7/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0121 - val_loss: 0.1160
# Epoch 8/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0111 - val_loss: 0.1066
# Epoch 9/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0100 - val_loss: 0.0915
# Epoch 10/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0090 - val_loss: 0.0800
# Epoch 11/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0080 - val_loss: 0.0685
# Epoch 12/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 0.0627
# Epoch 13/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0550
# Epoch 14/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0055 - val_loss: 0.0463
# Epoch 15/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0046 - val_loss: 0.0408
# Epoch 16/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0039 - val_loss: 0.0352
# Epoch 17/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 0.0283
# Epoch 18/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0030 - val_loss: 0.0249
# Epoch 19/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 0.0217
# Epoch 20/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0024 - val_loss: 0.0178
# Epoch 21/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0164
# Epoch 22/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0022 - val_loss: 0.0133
# Epoch 23/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0141
# Epoch 24/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0114
# Epoch 25/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0112
# Epoch 26/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0109
# Epoch 27/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0094
# Epoch 28/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0098
# Epoch 29/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0112
# Epoch 30/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0100
# Epoch 31/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0096
# Epoch 32/100
# 94/94 [==============================] - 0s 4ms/step - loss: 0.0020 - val_loss: 0.0091
# Epoch 33/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0105
# Epoch 34/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0099
# Epoch 35/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0092
# Epoch 36/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0098
# Epoch 37/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0104
# Epoch 38/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0111
# Epoch 39/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0103
# Epoch 40/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0101
# Epoch 41/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0093
# Epoch 42/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0128
# Epoch 43/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0103
# Epoch 44/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0103
# Epoch 45/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0103
# Epoch 46/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0106
# Epoch 47/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0092
# Epoch 48/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0095
# Epoch 49/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0107
# Epoch 50/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0096
# Epoch 51/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0096
# Epoch 52/100
# 94/94 [==============================] - 0s 4ms/step - loss: 0.0020 - val_loss: 0.0097
# Epoch 53/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0097
# Epoch 54/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0091
# Epoch 55/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0098
# Epoch 56/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0095
# Epoch 57/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0087
# Epoch 58/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0117
# Epoch 59/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0108
# Epoch 60/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0104
# Epoch 61/100
# 94/94 [==============================] - 0s 4ms/step - loss: 0.0021 - val_loss: 0.0108
# Epoch 62/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0091
# Epoch 63/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0106
# Epoch 64/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0107
# Epoch 65/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0095
# Epoch 66/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0102
# Epoch 67/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0104
# Epoch 68/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0108
# Epoch 69/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0101
# Epoch 70/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0114
# Epoch 71/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0108
# Epoch 72/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0096
# Epoch 73/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0099
# Epoch 74/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0098
# Epoch 75/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0098
# Epoch 76/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0106
# Epoch 77/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0111
# Epoch 78/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0094
# Epoch 79/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0099
# Epoch 80/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0112
# Epoch 81/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0094
# Epoch 82/100
# 94/94 [==============================] - 0s 4ms/step - loss: 0.0020 - val_loss: 0.0099
# Epoch 83/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0106
# Epoch 84/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0104
# Epoch 85/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0096
# Epoch 86/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0104
# Epoch 87/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0103
# Epoch 88/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0095
# Epoch 89/100
# 94/94 [==============================] - 0s 4ms/step - loss: 0.0020 - val_loss: 0.0102
# Epoch 90/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0109
# Epoch 91/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0088
# Epoch 92/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0113
# Epoch 93/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0117
# Epoch 94/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0103
# Epoch 95/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0098
# Epoch 96/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0112
# Epoch 97/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0124
# Epoch 98/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0092
# Epoch 99/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0115
# Epoch 100/100
# 94/94 [==============================] - 0s 3ms/step - loss: 0.0020 - val_loss: 0.0100

# %%
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

# %%
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform([testY])

# %%
# calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 22.64 RMSE
# Test Score: 51.79 RMSE

# %%
# shift train predictions for plotting
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(dataset)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

# %%
# plot baseline and predictions
plt.figure(figsize=(10,6))
plt.plot(scaler.inverse_transform(dataset), label='Real Data')
plt.plot(trainPredictPlot, label='trainPredict')
plt.plot(testPredictPlot, label='testPredict')
plt.legend(title="Notes")
plt.show()

# %%
# ws = {}
# for layer in model.layers:
# ws[layer.name] = layer.get_weights()
# ws

# %%
# x_new = 432 => next time = ?
x_new = scaler.transform([[432]])
x_new = numpy.reshape(x_new, (1, 1, 1))
y_new = model.predict(x_new)
y_new = scaler.inverse_transform(y_new)
y_new
# Out:
# array([[409.51892]], dtype=float32)

# %%
# Với lượng dữ liệu ít, bài toán này hoạt độnng chưa được tốt.
