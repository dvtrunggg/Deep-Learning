# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, Model 
from tensorflow.keras.layers import Dense, Input

from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# %cd '/content/gdrive/My Drive/LDS8_K275_ONLINE_DinhVietTrung'
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/LDS8_K275_ONLINE_DinhVietTrung

# %%
data = plt.imread('data/stop_sign_1.jpg')
plt.imshow(data)
plt.show()

# %%
data.shape
# Out:
# (168, 299, 3)

# %%
data[0,0]
# Out:
# array([  0,  98, 166], dtype=uint8)

# %%
data[100, 200]
# Out:
# array([201,  39,  50], dtype=uint8)

# %%
data_new = data.copy()
data_new[:10, :10, 0] = 1
data_new[:10, :10, 1] = 0
data_new[:10, :10, 2] = 0

# %%
plt.imshow(data_new)
plt.show()
